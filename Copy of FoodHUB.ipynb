# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# %%
# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read the data
df = pd.read_csv('Foodhub_order.csv')

# %%
# returns the first 5 rows
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# ...

# %%
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24
# ...

# %% [markdown]
#  How many rows and columns are present in the data?

# %%
df.shape
# Out:
# (1898, 9)

# %% [markdown]
# What are the datatypes of the different columns in the dataset? (The info() function can be used)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 133.6+ KB

# %% [markdown]
#  Are there any missing values in the data? If yes, treat them using an appropriate method

# %%
df.isnull().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64

# %%
df_dropped = df.dropna()

# %% [markdown]
#  Check the statistical summary of the data. What is the minimum, average, and maximum time it takes for food to be prepared once an order is placed

# %%
df['food_preparation_time'].describe()
# Out:
# count    1898.000000
# mean       27.371970
# std         4.632481
# min        20.000000
# 25%        23.000000
# 50%        27.000000
# 75%        31.000000
# max        35.000000
# Name: food_preparation_time, dtype: float64

# %% [markdown]
# How many orders are not rated?

# %%
#df['rating'].isnull().sum()
#measure the length of the subset of the dataframe in which the rating is 'Not given'
not_rated = df[df.rating=='Not given']
len(not_rated)
# Out:
# 736

# %% [markdown]
# Explore all the variables and provide observations on their distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.)

# %%
df.nunique()
# Out:
# order_id                 1898
# customer_id              1200
# restaurant_name           178
# cuisine_type               14
# cost_of_the_order         312
# day_of_the_week             2
# rating                      4
# food_preparation_time      16
# delivery_time              19
# dtype: int64

# %%
np.histogram_bin_edges(df['food_preparation_time'])
# Out:
# array([20. , 21.5, 23. , 24.5, 26. , 27.5, 29. , 30.5, 32. , 33.5, 35. ])

# %%
ax = sns.histplot(df.customer_id.value_counts())
ax.set(xlabel="Number of orders per customer")
ax.set(ylabel='Number of customers')
plt.show()

# %%
#plots histogram of the costs of all orders within the dataset
ax=sns.histplot(data=df, x='cost_of_the_order', binwidth=10, binrange=(0,40))
ax.set(xlabel='Cost of the order ($)')
ax.set(ylabel='Number of orders')
ax.set(xticks=[0,10,20,30,40])
plt.show()

# %%
#returns countplot of orders by day of the week the order was placed (i.e. weekday or weekend)
ax=sns.countplot(data=df,x='day_of_the_week')
ax.set(xlabel='day_of_the_week')
ax.set(ylabel='Number of orders')
plt.show()

# %%
ax = sns.boxplot(x=df['food_preparation_time'])
ax.set(xlabel='food_preparation_time')
ax.set(ylabel='Numbers of orders')
plt.show()

# %% [markdown]
# Which are the top 5 restaurants in terms of the number of orders received

# %%
top_restaurants = df['restaurant_name'].value_counts().nlargest(5)
print(top_restaurants)
# Out:
# restaurant_name
# Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
# Name: count, dtype: int64

# %% [markdown]
# Which is the most popular cuisine on weekends

# %%
weekend_orders = df[df['day_of_the_week'].isin(['Weekend'])]
popular_cuisines = weekend_orders['cuisine_type'].value_counts()
print(popular_cuisines)
# Out:
# cuisine_type
# American          415
# Japanese          335
# Italian           207
# Chinese           163
# Mexican            53
# Indian             49
# Mediterranean      32
# Middle Eastern     32
# Thai               15
# French             13
# Korean             11
# Southern           11
# Spanish            11
# Vietnamese          4
# Name: count, dtype: int64

# %% [markdown]
# with indexes

# %%
print(popular_cuisines.index[7])
# Out:
# Middle Eastern

# %% [markdown]
# What percentage of the orders cost more than 20 dollars

# %%
expensive_orders = df[df['cost_of_the_order'] > 20]
percentage = (len( weekend_orders) / len(df)) * 100
print(percentage)
# Out:
# 71.18018967334035

# %%
expensive_orders = df[df['cost_of_the_order'] > 20]
percentage = (len( expensive_orders) / len(df)) * 100
print(percentage)
# Out:
# 29.24130663856691

# %% [markdown]
# What is the mean order delivery time

# %%
mean_delivery_time = df['delivery_time'].mean()
print(mean_delivery_time)
# Out:
# 24.161749209694417

# %% [markdown]
# The company has decided to give 20% discount vouchers to the top 3 most frequent customers. Find the IDs of these customers and the number of orders they placed

# %%
top_customers = df['customer_id'].value_counts()
top_3_customers = top_customers.head(3)
print(top_3_customers)
# Out:
# customer_id
# 52832    13
# 47440    10
# 83287     9
# Name: count, dtype: int64

# %% [markdown]
# Perform a multivariate analysis to explore relationships between the important variables in the dataset. (It is a good idea to explore relations between numerical variables as well as relations between numerical and categorical variables)

# %%
sns.pairplot(data=df)
plt.show()

# %%
relevant_columns = ['cost_of_the_order', 'delivery_time', 'food_preparation_time','rating' ]

# Create a pairplot
sns.pairplot(df[relevant_columns])
plt.show()

# %% [markdown]
# The company wants to provide a promotional offer in the advertisement of the restaurants. The condition to get the offer is that the restaurants must have a rating count of more than 50 and the average rating should be greater than 4. Find the restaurants fulfilling the criteria to get the promotional offer

# %%
df3=df.copy()
df3.rating.replace("Not given",0,inplace=True)#
df3.rating=pd.to_numeric(df3.rating)
df3.rating.replace(0,np.nan,inplace=True)
df3.rating.count()
# Out:
# 1162

# %%
sns.countplot(data=df3,x='rating')
plt.show()

# %%
df3.groupby('restaurant_name')['rating'].count().sort_values(ascending=False).reset_index().head()
# Out:
#              restaurant_name  rating
# 0                Shake Shack     133
# 1          The Meatball Shop      84
# 2          Blue Ribbon Sushi      73
# 3  Blue Ribbon Fried Chicken      64
# 4           RedFarm Broadway      41
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_28.groupby('restaurant_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %% [markdown]
# The company charges the restaurant 25% on the orders having cost greater than 20 dollars and 15% on the orders having cost greater than 5 dollars. Find the net revenue generated by the company across all orders.

# %%
revenue_over_20 = df[df['cost_of_the_order'] > 20]['cost_of_the_order'].sum() * 0.25
revenue_over_5 = df[(df['cost_of_the_order'] > 5) & (df['cost_of_the_order'] <= 20)]['cost_of_the_order'].sum() * 0.15
total_revenue = revenue_over_20 + revenue_over_5
print(total_revenue)
# Out:
# 6166.303

# %% [markdown]
# The company wants to analyze the total time required to deliver the food. What percentage of orders take more than 60 minutes to get delivered from the time the order is placed? (The food has to be prepared and then delivered

# %%
df['total_time'] = df['food_preparation_time'] + df['delivery_time']
long_deliveries = df[df['total_time'] > 60]
percentage_long_deliveries = (len(long_deliveries) / len(df)) * 100
print(percentage_long_deliveries)
# Out:
# 10.537407797681771

# %% [markdown]
# The company wants to analyze the delivery time of the orders on weekdays and weekends. How does the mean delivery time vary during weekdays and weekends

# %%
weekday_orders = df[df['day_of_the_week'] == 'Weekday']
mean_weekday_delivery_time = weekday_orders['delivery_time'].mean()
print("Mean delivery time on weekdays:", mean_weekday_delivery_time)
# Out:
# Mean delivery time on weekdays: 28.340036563071298

# %% [markdown]
# What are your conclusions from the analysis? What recommendations would you like to share to help improve the business? (You can use cuisine type and feedback ratings to drive your business recommendations.)
#
# Conclusion : The number of drivers available to deliver orders appear to be overwhelmed by higher weekend volumes, causing delivery times to increase by 26%
# However, the proportions of lower rated (3 or 4 star) weekend orders are actually not significantly different than weekday orders
# Therefore, the additional benefits to customers from lowering delivery times during the weekend may not be worth the costs of additional driver incentives
